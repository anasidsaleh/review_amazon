# %%
import requests
from bs4 import BeautifulSoup as sp
import csv
import pandas as pd
import numpy as np

# %%
#Enter the url of the review page and delete the number of the the page in the end of the url 
urls = ["https://www.amazon.fr/Huile-Coco-Bio-500-ml/product-reviews/B072152F98/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=", 
        "https://www.amazon.fr/Jardin-Bio-Beurre-Cacahu%C3%A8te-350/product-reviews/B082VW86J8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=","https://www.amazon.fr/Cosses-psyllium-MeaVita-indiennes-v%C3%A9g%C3%A9taliennes/product-reviews/B01LZGXOG3/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=","https://www.amazon.fr/Caf%C3%A9-Royal-Compatibles-Nespresso-Solutions/product-reviews/B07G234DPL/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=" ,
        "https://www.amazon.fr/Graines-Chia-Bio-Sup%C3%A9rieure-amOseeds/product-reviews/B081B4Z9J9/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/v%C3%A9g%C3%A9talienne-meilleure-biodisponibilit%C3%A9-antiagglom%C3%A9rant-magn%C3%A9sium/product-reviews/B075TL67K8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Mundo-Feliz-sachets-enti%C3%A8res-500/product-reviews/B07WXM7DB8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Huile-biologique-extra-vierge-MeaVita/product-reviews/B013GBN8MG/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Bjorg-Pain-Grill%C3%A9-Bl%C3%A9-Complet/product-reviews/B082VVPWLH/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Bjorg-Muesli-aux-Prot%C3%A9ines-Soja/product-reviews/B07YQFS8B9/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Huile-Coco-Extra-Vierge-1000/product-reviews/B01JIB2T32/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Bialetti-Perfetto-Classico-Classic-Torr%C3%A9faction/product-reviews/B08D6Z9ST9/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Naissance-Huile-V%C3%A9g%C3%A9tale-dArgan-naturelle/product-reviews/B004RG9WAC/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Huile-Ricin-1L-Pure-Naturelle/product-reviews/B07PJLB756/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Huile-v%C3%A9g%C3%A9tale-dargan-naturelle-100/product-reviews/B01LYI4SB3/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/Naturelle-Press%C3%A9e-Acc%C3%A9l%C3%A8re-Cheveux-cheveux/product-reviews/B07GCQQLJT/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        "https://www.amazon.fr/BIONOBLE-Naturelle-Mascara-Sourcils-Cheveux/product-reviews/B07RCB88TY/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=",
        ]

#Coonection with the amazon page
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36','referer':'https://www.amazon.com/s?k=nike+shoes+men&crid=28WRS5SFLWWZ6&sprefix=nike%2Caps%2C357&ref=nb_sb_ss_organic-diversity_2_4'}
cookie = {}
def Searchreviews(url):
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

#Scraping function
data_review = []
def scrap_review(soup):
  div = soup.find_all("div", {"data-hook":"review"})
  try:
    for i in div:
      review = {
          'Nom': i.find("span", {'class': 'a-profile-name'}).text.strip(),
          'Titre': i.find("a",{'data-hook':'review-title'}).text.strip(),
          'Texte': i.find("span",{'data-hook':'review-body'}).text.strip(),
          'Evaluation': i.find("span",{'class':'a-icon-alt'}).text.strip()[0:3]
      }
      
      data_review.append(review)
  
  except:
    pass

#running the functions 
for base_url in urls:
  for i in range(1,50):
    number_page = i
    url = base_url + str(number_page)
    r = Searchreviews(url)
    soup = sp(r.text, 'html.parser')
    scrap_review(soup)
    #Reviews in each page
    print(len(data_review))
    #condition if we hit the end of reviews's pages
    if not soup.find('li', {"class": "a-disabled a-last"}):
      pass
    else:
      break

#Coverting the data to a csv files
df = pd.DataFrame.from_dict(data_review)
df.to_csv('review_data.csv')
# Out:
# https://www.amazon.fr/Huile-Coco-Bio-500-ml/product-reviews/B072152F98/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# 10
# https://www.amazon.fr/Huile-Coco-Bio-500-ml/product-reviews/B072152F98/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# 20
# https://www.amazon.fr/Huile-Coco-Bio-500-ml/product-reviews/B072152F98/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# 30
# https://www.amazon.fr/Huile-Coco-Bio-500-ml/product-reviews/B072152F98/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# 40
# https://www.amazon.fr/Huile-Coco-Bio-500-ml/product-reviews/B072152F98/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# 50
# https://www.amazon.fr/Huile-Coco-Bio-500-ml/product-reviews/B072152F98/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# 60
# ...
